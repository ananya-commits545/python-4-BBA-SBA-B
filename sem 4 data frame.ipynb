# %%
import pandas as pd

# %%
import numpy as np

# %%
data={"Region":["Asia","Asia","Europe","Europe","America","America"],"Country":["China","India","France","Germany","Oman","Canada"],"Year":[2025,2024,2023,2022,2021,2020],"Sales":[20000,30000,40000,50000,60000,70000],"Profit":[300,400,500,600,700,800]}
df=pd.DataFrame(data)

# %%
df
# Out:
#     Region  Country  Year  Sales  Profit
# 0     Asia    China  2025  20000     300
# 1     Asia    India  2024  30000     400
# 2   Europe   France  2023  40000     500
# 3   Europe  Germany  2022  50000     600
# 4  America     Oman  2021  60000     700
# 5  America   Canada  2020  70000     800

# %%
df.groupby("Region")[["Profit","Year"]].mean()
# Out:
#          Profit    Year
# Region
# America   750.0  2020.5
# Asia      350.0  2024.5
# Europe    550.0  2022.5

# %%
ice_cream=["strawberry","chocolate","vanilla","tuttifruity"]

# %%
pd.Series(ice_cream)
# Out:
# 0     strawberry
# 1      chocolate
# 2        vanilla
# 3    tuttifruity
# dtype: object

# %%
lottery_number=[1,2,3,4,5]

# %%
pd.Series(lottery_number)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
sushiL={"Tuna":"Red",
       "Salmon":"Orange",
       "Eel":"Brown"}

# %%
pd.Series(sushiL)
# Out:
# Tuna         Red
# Salmon    Orange
# Eel        Brown
# dtype: object

# %%
#sth through method

# %%
price=pd.Series([23.5,45,78,2,5])

# %%
price
# Out:
# 0    23.5
# 1    45.0
# 2    78.0
# 3     2.0
# 4     5.0
# dtype: float64

# %%
price.sum()
# Out:
# 153.5

# %%
price.mean()
# Out:
# 30.7

# %%
price.product()
# Out:
# 824850.0

# %%
price.median()
# Out:
# 23.5

# %%
#attribute

# %%
adjectives=pd.Series(["Beautiful","Smart","Intelligent","Handsome","Smart"])
adjectives
# Out:
# 0      Beautiful
# 1          Smart
# 2    Intelligent
# 3       Handsome
# 4          Smart
# dtype: object

# %%
adjectives.size
# Out:
# 5

# %%
adjectives.values
# Out:
# array(['Beautiful', 'Smart', 'Intelligent', 'Handsome', 'Smart'],
#       dtype=object)

# %%
adjectives.is_unique
# Out:
# False

# %%
type(adjectives.values)
# Out:
# numpy.ndarray

# %%
#argument and parameter

# %%
weekdays=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
fruits=["Apple","Banana","Orange","Guava","Litchi","Kiwi","Mango"]

# %%
pd.Series(index=weekdays,data=fruits)
# Out:
# Monday        Apple
# Tuesday      Banana
# Wednesday    Orange
# Thursday      Guava
# Friday       Litchi
# Saturday       Kiwi
# Sunday        Mango
# dtype: object

# %%
pd.Series(fruits,weekdays)
# Out:
# Monday        Apple
# Tuesday      Banana
# Wednesday    Orange
# Thursday      Guava
# Friday       Litchi
# Saturday       Kiwi
# Sunday        Mango
# dtype: object
