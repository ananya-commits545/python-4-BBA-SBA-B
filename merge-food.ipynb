# %%
import pandas as pd
import numpy as np

# %%
customers=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\restaurant_customers.csv")

# %%
customers
# Out:
#        ID First Name Last Name  Gender       Company  \
# 0       1     Joseph   Perkins    Male       Dynazzy
# 1       2   Jennifer   Alvarez  Female          DabZ
# 2       3      Roger     Black    Male       Tagfeed
# 3       4     Steven     Evans    Male          Fatz
# 4       5       Judy  Morrison  Female       Demivee
# ..    ...        ...       ...     ...           ...
# 995   996      Debra    Garcia  Female  Dazzlesphere
# 996   997    Douglas    Bishop    Male      Livepath
# 997   998      Frank  Franklin    Male    Brainverse
# 998   999    Jessica     Burns  Female    Babbleblab
# 999  1000      Brian   Daniels    Male         Tazzy
#
#                         Occupation
# 0    Community Outreach Specialist
# 1          Senior Quality Engineer
# 2                Account Executive
# 3                 Registered Nurse
# 4                  Legal Assistant
# ..                             ...
# 995            Structural Engineer
# 996                    Developer I
# ...

# %%
food=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\restaurant_foods.csv")

# %%
food
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49
# 5        6       Pasta  13.99
# 6        7       Steak  24.99
# 7        8       Salad  11.25
# 8        9       Donut   0.99
# 9       10       Drink   1.75

# %%
week1=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\restaurant_week_1_sales.csv")

# %%
week1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
week1t=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\restaurant_week_1_times.csv")

# %%
week1t
# Out:
#     Time of Day
# 0      14:54:59
# 1      20:55:17
# 2      01:16:22
# 3      16:17:26
# 4      19:26:11
# ..          ...
# 245    04:44:14
# 246    07:46:21
# 247    20:45:08
# 248    01:09:06
# 249    18:18:50
#
# [250 rows x 1 columns]

# %%
week2=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\restaurant_week_2_sales.csv")

# %%
week2
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [250 rows x 2 columns]

# %%
len(week1)
# Out:
# 250

# %%
len(week2)
# Out:
# 250

# %%
pd.concat([week1, week2]) #used to merge
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %%
pd.concat([week1, week2], ignore_index=False)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %%
pd.concat([week1, week2], ignore_index=True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %%
pd.concat([week1, week2], keys=["Week1", "Week2"]).sort_index()
# Out:
#            Customer ID  Food ID
# Week1 0            537        9
#       1             97        4
#       2            658        1
#       3            202        2
#       4            155        9
# ...                ...      ...
# Week2 245          783       10
#       246          556       10
#       247          547        9
#       248          252        9
#       249          249        6
#
# [500 rows x 2 columns]

# %%
pd.concat([week1, week2], keys=["Week1", "Week2"])
# Out:
#            Customer ID  Food ID
# Week1 0            537        9
#       1             97        4
#       2            658        1
#       3            202        2
#       4            155        9
# ...                ...      ...
# Week2 245          783       10
#       246          556       10
#       247          547        9
#       248          252        9
#       249          249        6
#
# [500 rows x 2 columns]

# %%
df1=pd.DataFrame([1,2,3], columns=["A"])
df1
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
df2=pd.DataFrame([4,5,6], columns=["B"])
df2
# Out:
#    B
# 0  4
# 1  5
# 2  6

# %%
pd.concat([df1,df2])
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  NaN
# 2  3.0  NaN
# 0  NaN  4.0
# 1  NaN  5.0
# 2  NaN  6.0

# %%
pd.concat([df1,df2], axis="index")
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  NaN
# 2  3.0  NaN
# 0  NaN  4.0
# 1  NaN  5.0
# 2  NaN  6.0

# %%
pd.concat([df1,df2], axis="columns")
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
food.head(5)
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49

# %%
week1.head(5)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
#left merge

# %%
week1.merge(food, how="left",

# %%
week2.head(5)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %%
customers.head(5)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive
# 3   4     Steven     Evans    Male     Fatz               Registered Nurse
# 4   5       Judy  Morrison  Female  Demivee                Legal Assistant

# %%
week2.merge(customers, how="left", left_on="Customer ID", right_on="ID")
# Out:
#      Customer ID  Food ID   ID First Name   Last Name  Gender       Company  \
# 0            688       10  688       Carl  Williamson    Male    Thoughtmix
# 1            813        7  813     Johnny      Walker    Male        Kayveo
# 2            495       10  495    Deborah      Little  Female    Babbleblab
# 3            189        5  189      Roger      Gordon    Male       Skilith
# 4            267        3  267    Matthew        Wood    Male        Agimba
# ..           ...      ...  ...        ...         ...     ...           ...
# 245          783       10  783    Phyllis       Meyer  Female        Voolia
# 246          556       10  556     Samuel      Bailey    Male        Oyoloo
# 247          547        9  547       Tina     Watkins  Female  Thoughtstorm
# 248          252        9  252    Douglas      Powell    Male       Jetwire
# 249          249        6  249    Anthony   Carpenter    Male    Shuffletag
#
#                       Occupation
# ...

# %%
week2.merge(customers, how="left", left_on="Customer ID", right_on="ID").drop("ID", axis="columns")
# Out:
#      Customer ID  Food ID First Name   Last Name  Gender       Company  \
# 0            688       10       Carl  Williamson    Male    Thoughtmix
# 1            813        7     Johnny      Walker    Male        Kayveo
# 2            495       10    Deborah      Little  Female    Babbleblab
# 3            189        5      Roger      Gordon    Male       Skilith
# 4            267        3    Matthew        Wood    Male        Agimba
# ..           ...      ...        ...         ...     ...           ...
# 245          783       10    Phyllis       Meyer  Female        Voolia
# 246          556       10     Samuel      Bailey    Male        Oyoloo
# 247          547        9       Tina     Watkins  Female  Thoughtstorm
# 248          252        9    Douglas      Powell    Male       Jetwire
# 249          249        6    Anthony   Carpenter    Male    Shuffletag
#
#                       Occupation
# 0               Graphic Designer
# 1                   Developer II
# ...
