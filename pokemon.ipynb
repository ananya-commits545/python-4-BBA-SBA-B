# %%
import pandas as pd
import numpy as np

# %%
pokemon=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\pokemon.csv")

# %%
pokemon
# Out:
#               Name              Type
# 0        Bulbasaur     Grass, Poison
# 1          Ivysaur     Grass, Poison
# 2         Venusaur     Grass, Poison
# 3       Charmander              Fire
# 4       Charmeleon              Fire
# ...            ...               ...
# 1005  Iron Valiant   Fairy, Fighting
# 1006      Koraidon  Fighting, Dragon
# 1007      Miraidon  Electric, Dragon
# 1008  Walking Wake     Water, Dragon
# 1009   Iron Leaves    Grass, Psychic
#
# [1010 rows x 2 columns]

# %%
pokemon.groupby("Name")

# %%
#to show a particular column

# %%
pokemon=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\pokemon.csv",usecols=["Name"])

# %%
pokemon
# Out:
#               Name
# 0        Bulbasaur
# 1          Ivysaur
# 2         Venusaur
# 3       Charmander
# 4       Charmeleon
# ...            ...
# 1005  Iron Valiant
# 1006      Koraidon
# 1007      Miraidon
# 1008  Walking Wake
# 1009   Iron Leaves
#
# [1010 rows x 1 columns]

# %%
pokemon=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\pokemon.csv",usecols=["Name"]).squeeze("columns") #to convert from data frame to series

# %%
pokemon
# Out:
# 0          Grass, Poison
# 1          Grass, Poison
# 2          Grass, Poison
# 3                   Fire
# 4                   Fire
#               ...
# 1005     Fairy, Fighting
# 1006    Fighting, Dragon
# 1007    Electric, Dragon
# 1008       Water, Dragon
# 1009      Grass, Psychic
# Name: Type, Length: 1010, dtype: object

# %%
pokemon=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\pokemon.csv",usecols=["Type"]).squeeze("columns")

# %%
pokemon
# Out:
# 0          Grass, Poison
# 1          Grass, Poison
# 2          Grass, Poison
# 3                   Fire
# 4                   Fire
#               ...
# 1005     Fairy, Fighting
# 1006    Fighting, Dragon
# 1007    Electric, Dragon
# 1008       Water, Dragon
# 1009      Grass, Psychic
# Name: Type, Length: 1010, dtype: object

# %%
len(pokemon)
# Out:
# 1010

# %%
list(pokemon)
# Out:
# ['Grass, Poison',
#  'Grass, Poison',
#  'Grass, Poison',
#  'Fire',
#  'Fire',
#  'Fire, Flying',
#  'Water',
#  'Water',
#  'Water',
#  'Bug',
#  'Bug',
#  'Bug, Flying',
#  'Bug, Poison',
#  'Bug, Poison',
#  'Bug, Poison',
#  'Normal, Flying',
#  'Normal, Flying',
#  'Normal, Flying',
#  'Normal',
#  'Normal',
#  'Normal, Flying',
#  'Normal, Flying',
#  'Poison',
#  'Poison',
#  'Electric',
#  'Electric',
#  'Ground',
#  'Ground',
#  'Poison',
#  'Poison',
#  'Poison, Ground',
#  'Poison',
#  'Poison',
#  'Poison, Ground',
#  'Fairy',
#  'Fairy',
#  'Fire',
#  'Fire',
#  'Normal, Fairy',
#  'Normal, Fairy',
#  'Poison, Flying',
#  'Poison, Flying',
#  'Grass, Poison',
#  'Grass, Poison',
#  'Grass, Poison',
#  'Bug, Grass',
#  'Bug, Grass',
#  'Bug, Poison',
#  'Bug, Poison',
#  'Ground',
#  'Ground',
#  'Normal',
#  'Normal',
#  'Water',
#  'Water',
#  'Fighting',
#  'Fighting',
#  'Fire',
#  'Fire',
#  'Water',
#  'Water',
#  'Water, Fighting',
#  'Psychic',
#  'Psychic',
# ...

# %% [raw]
# max(pokemon)

# %%
min(pokemon)
# Out:
# 'Bug'

# %%
max(pokemon)
# Out:
# 'Water, Steel'

# %%
pokemon.shape
# Out:
# (1010,)
