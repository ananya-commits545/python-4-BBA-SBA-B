# %%
import pandas as pd
import numpy as np

# %%
nba=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\nba.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 nba=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\nba.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
nba
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 nba
#
# NameError: name 'nba' is not defined

# %%
nba.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 nba.head()
#
# NameError: name 'nba' is not defined

# %%
nba.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 nba.tail()
#
# NameError: name 'nba' is not defined

# %%
nba.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 nba.describe()
#
# NameError: name 'nba' is not defined

# %%
nba.info()

# %%
nba=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\nba.csv",usecols=["College"])

# %%
nba

# %%
nba.head()

# %%
nba.tail()

# %%
nba.sort_index(ascending=True)

# %%
nba=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\nba.csv",usecols=["Name"])

# %%
nba

# %%
nba.sort_values("Name",ascending=False)

# %%
nba=pd.read_csv(r"C:\Users\Asus\OneDrive\Desktop\Python sem4\nba.csv",index_col="Name")

# %%
nba

# %%
#to add coloumn - broadcast

# %%
nba["Salary"]*2

# %%
nba

# %%
double_sal=nba["Salary"]*2

# %%
nba

# %%
nba.sort_values("Name",ascending=True)

# %%
nba.sort_values(["Team","Position"],ascending=False])
# Out:
#   Cell In[7], line 1
#     nba.sort_values(["Team","Position"],ascending=False])
#                                                        ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
nba["Height"].str.split("-")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 nba["Height"].str.split("-")
#
# NameError: name 'nba' is not defined

# %%
nba[["feet","inch"]]=nba["Height"].str.split("-")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 nba[["feet","inch"]]=nba["Height"].str.split("-")
#
# NameError: name 'nba' is not defined

# %%
import pandas as pd

# %%
nba=pd.read_csv(r"C:\Users\Asus\Downloads\nba.csv")

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba["Height"].str.split("-")
# Out:
# 0       [6, 7]
# 1       [6, 5]
# 2       [6, 5]
# 3      [6, 10]
# 4      [6, 10]
#         ...
# 587     [6, 3]
# 588     [6, 4]
# 589    [6, 10]
# 590     [6, 5]
# 591        NaN
# Name: Height, Length: 592, dtype: object

# %%
nba[["feet","inch"]]=nba["Height"].str.split("-",expand=True)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary feet inch
# 0        Villanova   4556983.0    6    7
# 1       Fenerbahce  18700000.0    6    5
# ...

# %%
nba.info
# Out:
# <bound method DataFrame.info of                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary feet inch
# 0        Villanova   4556983.0    6    7
# 1       Fenerbahce  18700000.0    6    5
# ...

# %%
nba[["feet","inch"]]=nba[["feet","inch"]].apply(pd.to_numeric)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    488 non-null    float64
#  7   feet      585 non-null    float64
#  8   inch      585 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 41.8+ KB

# %%
nba["feet"]*30.48+nba["inch"]*2.54
# Out:
# 0      200.66
# 1      195.58
# 2      195.58
# 3      208.28
# 4      208.28
#         ...
# 587    190.50
# 588    193.04
# 589    208.28
# 590    195.58
# 591       NaN
# Length: 592, dtype: float64

# %%
nba["Height_in_centimeter"]=nba["feet"]*30.48+nba["inch"]*2.54

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary  feet  inch  Height_in_centimeter
# 0        Villanova   4556983.0   6.0   7.0                200.66
# ...

# %%
nba.drop("Height_in_centimeter",axis=1)
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary  feet  inch
# 0        Villanova   4556983.0   6.0   7.0
# 1       Fenerbahce  18700000.0   6.0   5.0
# ...
